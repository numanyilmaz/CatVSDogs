# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('https://query.data.world/s/13nf09e1owjzezj9ea01gicjp', index_col='Location')
df.head()
# Out:
#             Number of Households (in 1000)  \
# Location
# Alabama                               1828
# Arizona                               2515
# Arkansas                              1148
# California                           12974
# Colorado                              1986
#
#             Percentage of households with pets  \
# Location
# Alabama                                   59.5
# Arizona                                   59.5
# Arkansas                                  62.4
# California                                52.9
# Colorado                                  61.3
#
#             Number of Pet Households (in 1000)  Percentage of Dog Owners  \
# Location
# Alabama                                   1088                      44.1
# Arizona                                   1497                      40.1
# Arkansas                                   716                      47.9
# California                                6865                      32.8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Alabama to Wyoming
# Data columns (total 11 columns):
# Number of Households (in 1000)        49 non-null int64
# Percentage of households with pets    49 non-null float64
# Number of Pet Households (in 1000)    49 non-null int64
# Percentage of Dog Owners              49 non-null float64
# Dog Owning Households (1000s)         49 non-null int64
# Mean Number of Dogs per household     49 non-null float64
# Dog Population (in 1000)              49 non-null int64
# Percentage of Cat Owners              49 non-null float64
# Cat Owning Households                 49 non-null int64
# Mean Number of Cats                   49 non-null float64
# Cat Population                        49 non-null int64
# dtypes: float64(5), int64(6)
# memory usage: 4.6+ KB

# %%
df.describe()
# Out:
#        Number of Households (in 1000)  Percentage of households with pets  \
# count                       49.000000                           49.000000
# mean                      2403.897959                           56.859184
# std                       2514.054786                            6.931688
# min                        221.000000                           21.900000
# 25%                        765.000000                           53.600000
# 50%                       1759.000000                           56.800000
# 75%                       2632.000000                           61.300000
# max                      12974.000000                           70.800000
#
#        Number of Pet Households (in 1000)  Percentage of Dog Owners  \
# count                           49.000000                 49.000000
# mean                          1342.591837                 36.973469
# std                           1358.247246                  6.671169
# ...

# %%
dogs = df[['Percentage of Dog Owners', 'Dog Owning Households (1000s)','Mean Number of Dogs per household', 'Dog Population (in 1000)']]
dogs.head()
# Out:
#             Percentage of Dog Owners  Dog Owning Households (1000s)  \
# Location
# Alabama                         44.1                            807
# Arizona                         40.1                           1008
# Arkansas                        47.9                            550
# California                      32.8                           4260
# Colorado                        42.5                            845
#
#             Mean Number of Dogs per household  Dog Population (in 1000)
# Location
# Alabama                                   1.7                      1410
# Arizona                                   1.8                      1798
# Arkansas                                  2.0                      1097
# California                                1.6                      6687
# Colorado                                  1.6                      1349

# %%
dogs.plot.scatter(x='Percentage of Dog Owners', y='Dog Population (in 1000)', figsize=(15,5))

# %%
df.sort_values('Percentage of households with pets', ascending=False)
# Out:
#                       Number of Households (in 1000)  \
# Location
# Vermont                                          265
# New Mexico                                       773
# South Dakota                                     333
# Oregon                                          1505
# Maine                                            548
# Washington                                      2632
# Arkansas                                        1148
# West Virginia                                    765
# Idaho                                            568
# Wyoming                                          221
# Kentucky                                        1777
# Missouri                                        2498
# Montana                                          410
# Colorado                                        1986
# Kansas                                          1133
# Indiana                                         2478
# ...

# %%
df.nlargest(10, 'Percentage of households with pets').plot(figsize=(15,5))
